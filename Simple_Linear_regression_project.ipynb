# %% [markdown]
# ## Salaryíes_By_College

# %% [markdown]
# ### Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the dataset which is salaries-by-region

# %%
df = pd.read_csv("Salaries.csv")
X = df.iloc[:,[6,10,11]]
df.sample(15)
# Out:
# C:\Users\peter\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             Id          EmployeeName                       JobTitle   BasePay  \
# 76291    76292  Kathleen E Sakelaris                Manager IV, MTA    135039
# 16929    16930             PAUL FIOL          DEPUTY COURT CLERK II   70586.6
# 98010    98011    Tonette D Phillips        Parking Control Officer   47474.6
# 132726  132727   David J Christensen         Recreation Coordinator  60664.01
# 72676    72677       Trevor Greenlaw                 Pool Lifeguard     207.4
# 104790  104791    Shelley M Franklin  Housekeeper/Food Service Clnr   14862.3
# 119140  119141            Jay Primus                 Manager V, MTA   95133.4
# 94183    94184     Alfred  Fernandez                Health Worker 3   63931.2
# ...

# %%
df.head(15)
# Out:
#     Id        EmployeeName                                          JobTitle  \
# 0    1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1    2        GARY JIMENEZ                   CAPTAIN III (POLICE DEPARTMENT)
# 2    3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 3    4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    5     PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5    6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 6    7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 7    8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 8    9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9   10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...

# %%
df.tail(15)
# Out:
#             Id           EmployeeName                      JobTitle  \
# 148639  148640      Richard A Talbert                     Custodian
# 148640  148641     Charlene D Mccully       Parking Control Officer
# 148641  148642  Raphael Marquis Goins                  Museum Guard
# 148642  148643      Dominic C Marquez                   Sign Worker
# 148643  148644             Kim Brewer       Parking Control Officer
# 148644  148645           Randy D Winn  Stationary Eng, Sewage Plant
# 148645  148646       Carolyn A Wilson     Human Services Technician
# 148646  148647           Not provided                  Not provided
# 148647  148648         Joann Anderson   Communications Dispatcher 2
# 148648  148649            Leon Walker                     Custodian
# 148649  148650          Roy I Tillery                     Custodian
# 148650  148651           Not provided                  Not provided
# 148651  148652           Not provided                  Not provided
# ...

# %% [markdown]
# ## Insight into Dataset

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %% [markdown]
# ### Let check the shape of the dataset by using (df.shape) method to view the number of rows and columns of the dataset

# %%
df.shape
# Out:
# (148654, 13)

# %% [markdown]
# ### Check the dataset type by using "df.dtypes" method

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=148654, step=1)

# %% [markdown]
# ## Descriptive Statistic

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
df.describe(include = "all")
# Out:
#                    Id EmployeeName          JobTitle   BasePay  OvertimePay  \
# count   148654.000000       148654            148654  148049.0     148654.0
# unique            NaN       110811              2159  109900.0      66555.0
# top               NaN    Kevin Lee  Transit Operator       0.0          0.0
# freq              NaN           13              7036     875.0      66103.0
# mean     74327.500000          NaN               NaN       NaN          NaN
# std      42912.857795          NaN               NaN       NaN          NaN
# min          1.000000          NaN               NaN       NaN          NaN
# 25%      37164.250000          NaN               NaN       NaN          NaN
# 50%      74327.500000          NaN               NaN       NaN          NaN
# 75%     111490.750000          NaN               NaN       NaN          NaN
# max     148654.000000          NaN               NaN       NaN          NaN
#
# ...

# %%
df.describe().transpose()
# Out:
#                      count          mean           std      min        25%  \
# Id                148654.0  74327.500000  42912.857795     1.00  37164.250
# TotalPay          148654.0  74768.321972  50517.005274  -618.13  36168.995
# TotalPayBenefits  148654.0  93692.554811  62793.533483  -618.13  44065.650
# Year              148654.0   2012.522643      1.117538  2011.00   2012.000
# Notes                  0.0           NaN           NaN      NaN        NaN
#
#                        50%         75%        max
# Id                74327.50  111490.750  148654.00
# TotalPay          71426.61  105839.135  567595.43
# TotalPayBenefits  92404.09  132876.450  567595.43
# Year               2013.00    2014.000    2014.00
# Notes                  NaN         NaN        NaN

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df.hist(bins=50, figsize=(10,8))
plt.show()

# %% [markdown]
# ## Handling Missing Data

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#       Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  Benefits  \
# 0  False         False     False    False        False     False      True
# 1  False         False     False    False        False     False      True
# 2  False         False     False    False        False     False      True
# 3  False         False     False    False        False     False      True
# 4  False         False     False    False        False     False      True
#
#    TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# 0     False             False  False   True   False    True
# 1     False             False  False   True   False    True
# 2     False             False  False   True   False    True
# 3     False             False  False   True   False    True
# 4     False             False  False   True   False    True

# %% [markdown]
# ### Get the number of missing_data per column

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# Id
# False    148654
# Name: Id, dtype: int64
#
# EmployeeName
# False    148654
# Name: EmployeeName, dtype: int64
#
# JobTitle
# False    148654
# Name: JobTitle, dtype: int64
#
# BasePay
# False    148049
# True        605
# Name: BasePay, dtype: int64
#
# OvertimePay
# False    148654
# Name: OvertimePay, dtype: int64
#
# OtherPay
# False    148654
# Name: OtherPay, dtype: int64
#
# Benefits
# False    112495
# True      36159
# Name: Benefits, dtype: int64
#
# TotalPay
# False    148654
# Name: TotalPay, dtype: int64
#
# TotalPayBenefits
# False    148654
# Name: TotalPayBenefits, dtype: int64
#
# Year
# False    148654
# Name: Year, dtype: int64
#
# Notes
# True    148654
# Name: Notes, dtype: int64
#
# Agency
# False    148654
# Name: Agency, dtype: int64
#
# Status
# True     110535
# False     38119
# Name: Status, dtype: int64

# %% [markdown]
# ### How many missing_values do we have

# %%
missing_values_count = df.isnull().sum()
missing_values_count
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
total_cells = np.product(df.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 15.314499027685352

# %% [markdown]
# **About 15.3 % of the dataset has missing_values**

# %% [markdown]
# ## Drop the unnecessary columns

# %%
df.drop(["Status", "Notes","Benefits", "BasePay"], axis=1, inplace=True)
df.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#   OvertimePay OtherPay   TotalPay  TotalPayBenefits  Year         Agency
# 0           0   400184  567595.43         567595.43  2011  San Francisco
# ...

# %% [markdown]
# ### Check missing_Values after the columns dropped

# %%
df.isnull().any()
# Out:
# Id                  False
# EmployeeName        False
# JobTitle            False
# OvertimePay         False
# OtherPay            False
# TotalPay            False
# TotalPayBenefits    False
# Year                False
# Agency              False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# OvertimePay         0
# OtherPay            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %% [markdown]
# #### Check the Total Missing_Values after the columns dropped

# %%
total_cells = np.product(df.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 22.120943039989953

# %% [markdown]
# **About 22 % of the dataset was considered as missing_values**

# %% [markdown]
# ### Check how the dataset is been displayed by using df.info method

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   OvertimePay       148654 non-null  object
#  4   OtherPay          148654 non-null  object
#  5   TotalPay          148654 non-null  float64
#  6   TotalPayBenefits  148654 non-null  float64
#  7   Year              148654 non-null  int64
#  8   Agency            148654 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 10.2+ MB

# %%
df.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# OvertimePay          object
# OtherPay             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Agency               object
# dtype: object

# %% [markdown]
# ### Check the value_counts of each object

# %%
df["EmployeeName"].value_counts().to_frame()
# Out:
#                      EmployeeName
# Kevin Lee                      13
# Richard Lee                    11
# Steven Lee                     11
# William Wong                   11
# Michael Wong                    9
# ...                           ...
# Robert Debiasio                 1
# Clayton Bullock                 1
# BENJAMIN ROSENFIELD             1
# Anthony Lococo                  1
# CYRIL KHOO                      1
#
# [110811 rows x 1 columns]

# %%
df["JobTitle"].value_counts().to_frame()
# Out:
#                                                     JobTitle
# Transit Operator                                        7036
# Special Nurse                                           4389
# Registered Nurse                                        3736
# Public Svc Aide-Public Works                            2518
# Police Officer 3                                        2421
# ...                                                      ...
# TRANSIT POWER LINE WORKER SUPERVISOR II                    1
# ASSISTANT DIRECTOR OF CLINICAL SERVICES II                 1
# AIRPORT ASSISTANT DEPUTY DIRECTOR, BUSINESS ADMINI         1
# SENIOR MATERIALS AND SUPPLIES SUPERVISOR                   1
# SENIOR OFFSET MACHINE OPERATOR                             1
#
# [2159 rows x 1 columns]

# %%
df["OvertimePay"].value_counts().to_frame()
# Out:
#          OvertimePay
# 0.0            66103
# 0.00           11218
# 681.23            41
# 10.68             41
# 152.13            38
# ...              ...
# 2040.47            1
# 7910.9             1
# 4212.38            1
# 570.97             1
# 728.98             1
#
# [66555 rows x 1 columns]

# %%
df["OtherPay"].value_counts().to_frame()
# Out:
#          OtherPay
# 0.0         35218
# 0.00         6382
# 624.0        1695
# 250.0         809
# 648.0         739
# ...           ...
# 4149.96         1
# 1525.36         1
# 4707.65         1
# 1943.65         1
# 6325.64         1
#
# [84968 rows x 1 columns]

# %%
df["Agency"].value_counts().to_frame()
# Out:
#                Agency
# San Francisco  148654

# %% [markdown]
# ## Dummy Variable

# %%
dummy_variable_1 = pd.get_dummies(df["Agency"])
dummy_variable_1
# Out:
#         San Francisco
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   1
# ...               ...
# 148649              1
# 148650              1
# 148651              1
# 148652              1
# 148653              1
#
# [148654 rows x 1 columns]

# %%
dummy_variable_1.rename(columns={"Agency":"San Francisco"}, inplace=True)
dummy_variable_1.head()
# Out:
#    San Francisco
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
df = pd.concat([df, dummy_variable_1], axis=1)

#drop the original data
df.drop("Agency", axis=1, inplace=True)

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#   OvertimePay OtherPay   TotalPay  TotalPayBenefits  Year  San Francisco
# 0           0   400184  567595.43         567595.43  2011              1
# 1      245132   137811  538909.28         538909.28  2011              1
# 2      106088  16452.6  335279.91         335279.91  2011              1
# 3     56120.7   198307  332343.61         332343.61  2011              1
# 4        9737   182235  326373.19         326373.19  2011              1

# %% [markdown]
# ### Declare the column you want to use as features

# %%
features = ["Id"]

# %% [markdown]
# ### Specify the Prediction Target

# %%
target = ["Year"]

# %% [markdown]
# ### Extract features and target into separate dataframe

# %%
X = df[features]

# %%
y = df[target]

# %%
print(X)
# Out:
#             Id
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ...        ...
# 148649  148650
# 148650  148651
# 148651  148652
# 148652  148653
# 148653  148654
#
# [148654 rows x 1 columns]

# %%
print(y)
# Out:
#         Year
# 0       2011
# 1       2011
# 2       2011
# 3       2011
# 4       2011
# ...      ...
# 148649  2014
# 148650  2014
# 148651  2014
# 148652  2014
# 148653  2014
#
# [148654 rows x 1 columns]

# %% [markdown]
# ### Split the dataset into Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
print(X_train)
# Out:
#             Id
# 82557    82558
# 6731      6732
# 145071  145072
# 36594    36595
# 96745    96746
# ...        ...
# 41993    41994
# 97639    97640
# 95939    95940
# 117952  117953
# 43567    43568
#
# [118923 rows x 1 columns]

# %%
print(X_test)
# Out:
#             Id
# 16864    16865
# 21794    21795
# 11328    11329
# 59437    59438
# 104101  104102
# ...        ...
# 132849  132850
# 113941  113942
# 56964    56965
# 133353  133354
# 63070    63071
#
# [29731 rows x 1 columns]

# %%
print(y_train)
# Out:
#         Year
# 82557   2013
# 6731    2011
# 145071  2014
# 36594   2012
# 96745   2013
# ...      ...
# 41993   2012
# 97639   2013
# 95939   2013
# 117952  2014
# 43567   2012
#
# [118923 rows x 1 columns]

# %%
print(y_test)
# Out:
#         Year
# 16864   2011
# 21794   2011
# 11328   2011
# 59437   2012
# 104101  2013
# ...      ...
# 132849  2014
# 113941  2014
# 56964   2012
# 133353  2014
# 63070   2012
#
# [29731 rows x 1 columns]

# %% [markdown]
# ### Train the Simpl Linear Regression on the Training set

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### Predict the Test result

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([[2011.07400923],
#        [2011.19830998],
#        [2010.93442931],
#        ...,
#        [2012.08505594],
#        [2014.0110621 ],
#        [2012.23900734]])

# %% [markdown]
# ## Visualising the Training set

# %%
plt.scatter(X_train, y_train, color = "red")
plt.plot(X_train, regressor.predict(X_train), color = "blue")
plt.xlabel("Id Payment")
plt.ylabel("Years of Payment")
plt.title("Id Payment vs Years of Payment ")
plt.show()

# %% [markdown]
# ### Visualising the Test set

# %%
plt.scatter(X_test, y_test, color = "red")
plt.plot(X_train, regressor.predict(X_train), color = "blue")
plt.xlabel("Id Payment")
plt.ylabel("Years of Payment")
plt.title("Id Payment vs Years of Payment ")
plt.show()

# %%
print(regressor.predict([[2010]]))
# Out:
# [[2010.69946811]]

# %% [markdown]
# ### Evaluating Model Performace

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9365178014921961
